# %% [markdown]
# # Logistic Regression usng sklearn

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
#load data
data=pd.read_csv('Submission_titanic.csv')
data.head()
data.count()
# Out:
# Unnamed: 0     418
# PassengerId    418
# Sex            418
# Age            418
# Fare           418
# Cabin          418
# Embarked       418
# Title          418
# FamilySize     418
# Survived       418
# dtype: int64

# %%
################################ ANALYSING DATA ##############################

# static data class wise represent by seaborn

sns.countplot(x='Survived',hue='Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Cabin',hue='Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='count'>

# %%
sns.barplot(x='Sex',y='Survived',data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
############histogram of an attribute
data['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
############################################# DATA WRANGLING
############################################ : REMOVE NAN VALUES

#CHECK NULL VALUES
data.isnull().sum()

data.drop('Cabin',axis=1,inplace=True)
data.isnull().sum()
data.dropna(inplace=True)
sns.heatmap(data.isnull())
data.isnull().sum()        #data is wrangled
# Out:
# Unnamed: 0     0
# PassengerId    0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# Title          0
# FamilySize     0
# Survived       0
# dtype: int64

# %%
###################################### dumming the data
sex=pd.get_dummies(titanic_data['Sex'],drop_first=True)
embarked=pd.get_dummies(titanic_data['Embarked'],drop_first=True)
pclass=pd.get_dummies(titanic_data['Pclass'],drop_first=True)
print(sex)
titanic_data=pd.concat([titanic_data,sex,embarked,pclass],axis=1)
titanic_data.head()
titanic_data.drop(['Name','Sex','Embarked','Ticket','PassengerId','Cabin'],axis=1,inplace=True)
titanic_data

# %%
####################################### TRAINING AND TESTING DATA
Y=data['Survived']
X=data[['Fare','Sex']]
# X1=X.reshape(-1,1)

# %%
#train data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, random_state=1, test_size=0.33)

# %%
#fit logistically
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
y_predict=log.predict(X_test)

score =accuracy_score(Y_test,y_predict)
print('Accuracy = ',score*100,'%')
# Out:
# Accuracy =  92.02898550724638 %
